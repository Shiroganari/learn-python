# %%
from week2 import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0d27473b4b8a> in <module>()
# ----> 1 from week2 import *
#
# ModuleNotFoundError: No module named 'week2'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # Основные структуры данных языка Python

# %% [markdown]
# ## Содержание
#
# * [Задача 1](#Задача-1)
# * [Задача 2](#Задача-2)
# * [Задача 3](#Задача-3)
# * [Задача 4](#Задача-4)
# * [Задача 5](#Задача-5)
# * [Задача 6](#Задача-6)
# * [Задача 7](#Задача-7)
# * [Задача 8](#Задача-8)
# * [Задача 9](#Задача-9)
# * [Задача 10](#Задача-10)

# %% [markdown]
# ## Задача 1
#
# Написать функцию `head(fname, n)`, которая принимает имя файла `fname` и количество требуемых строк `n` и возвращает список первых `n` строк файла; если `n` не задано, то возвращаются первые 5 строк.
#
# Пример.
#
# Пусть файл `text.txt` содержит следующий текст:
#
# *Humpty Dumpty sat on a wall,
# Humpty Dumpty had a great fall.
# All the king's horses,
# And all the king's men,
# Couldn't put Humpty together again.*
#
# Тогда
# ```python
# >> head('text.txt', 2)
# >> ['Humpty Dumpty sat on a wall,\n', 'Humpty Dumpty had a great fall.\n']
# ```
#
# **(!)** При решении задачи размерами файла пренебречь.

# %%
# Решение

# def head(ENTER YOUR CODE HERE):
#     f = open(ENTER YOUR CODE HERE)
#     text = f.readlines()
#     f.close()
#   
#     ENTER YOUR CODE HERE  # учтите ситуацию, когда количество строк в файле может быть меньше n
# 
#     return ENTER YOUR CODE HERE

# %%
# Проверка

check_task(head('text.txt'), '9a578')
check_task(head('text.txt', 1), '2acde')
check_task(head('text.txt', 2), 'd062b')

# %% [markdown]
# [к содержанию](#Содержание)

# %% [markdown]
# ## Задача 2
#
# Написать функцию `tail(fname, n)`, которая принимает имя файла `fname` и количество требуемых строк `n` и возвращает список последних `n` строк файла; если `n` не задано, то возвращаются последние 5 строк.
#
# Пример.
#
# Пусть файл `text.txt` содержит следующий текст:
#
# *Humpty Dumpty sat on a wall,
# Humpty Dumpty had a great fall.
# All the king's horses,
# And all the king's men,
# Couldn't put Humpty together again.*
#
# Тогда
# ```python
# >> tail('text.txt', 2)
# >> ["And all the king's men,\n", "Couldn't put Humpty together again."]
# ```
#
# **(!)** При решении задачи размерами файла пренебречь.

# %%
# Решение

# def tail(ENTER YOUR CODE HERE):
#     f = open(ENTER YOUR CODE HERE)
#     text = ENTER YOUR CODE HERE
#     f.close()
    
#     ENTER YOUR CODE HERE  # учтите ситуацию, когда файл короче числа запрашиваемых строк
    
#     return ENTER YOUR CODE HERE

# %%
# Проверка

check_task(tail('text.txt'), '9a578')
check_task(tail('text.txt', 1), '89571')
check_task(tail('text.txt', 2), '8f95e')

# %% [markdown]
# [к содержанию](#Содержание)

# %% [markdown]
# ## Задача 3
#
# Написать функцию `wc1(fname)`, которая принимает имя файла `fname` и возвращает кортеж `(nlines, nwords, nchars)`, где `nlines` - количество строк, `nwords` - количество слов, `nchars` - количество символов (включая пробелы, символы перевода строки и табуляции).
#
# Пример.
#
# Пусть файл `text.txt` содержит следующий текст:
#
# *Humpty Dumpty sat on a wall,
# Humpty Dumpty had a great fall.
# All the king's horses,
# And all the king's men,
# Couldn't put Humpty together again.*
#
# Тогда
# ```python
# >> wc1('text.txt')
# >> (5, 26, 143)
# ```
#
# **(!)** При решении задачи размерами файла пренебречь.

# %%
# Решение

# def wc1(fname):
#     f = open(fname)
#     text = f.read()
#     f.close()
    
#     ENTER YOUR CODE HERE

#     return (nlines, nwords, nchars)

# %%
# Проверка

check_task(wc1('text.txt'), '2faba')
check_task(wc1('text2.txt'), 'f51cc')

# %% [markdown]
# [к содержанию](#Содержание)

# %% [markdown]
# ## Задача 4
#
# Написать функцию `cleanup(text, badchars)`, которая принимает строку `text` и очищает её от "плохих" символов, заданных строкой `badchars`.
#
# Пример.
#
# ```python
# >> cleanup('hello,\tworld!\n', '\n \t')
# >> 'hello,world!'
# ```

# %%
# Решение

# def cleanup(text, badchars):
# 
#     ENTER YOUR CODE HERE
# 
#     return ENTER YOUR CODE HERE

# %%
# Проверка

check_task(cleanup('hello,\tworld!\n', '\n \t'), '46d92')
check_task(cleanup('dict([(1, "one"), (2, "two")])', '(", ")'), '4dbb7')

# %% [markdown]
# [к содержанию](#Содержание)

# %% [markdown]
# ## Задача 5
#
# Написать функцию `wc2(fname)`, которая принимает имя файла `fname` и возвращает кортеж `(nlines, nwords, nchars)`, где `nlines` - количество строк, `nwords` - количество слов, `nchars` - количество символов (без учёта пробелов, символов перевода строки и табуляций).
#
# Пример.
#
# Пусть файл `text.txt` содержит следующий текст:
#
# *Humpty Dumpty sat on a wall,
# Humpty Dumpty had a great fall.
# All the king's horses,
# And all the king's men,
# Couldn't put Humpty together again.*
#
# Тогда
# ```python
# >> wc2('text.txt')
# >> (5, 26, 118)
# ```
#
# **(!)** При решении задачи размерами файла пренебречь.

# %%
# Решение

# def wc2(fname):
#     f = open(fname)
#     text = f.read()
#     f.close()
    
#     ENTER YOUR CODE HERE

#     return (nlines, nwords, nchars)

# %%
# Проверка

check_task(wc2('text.txt'), '04cdc')
check_task(wc2('text2.txt'), 'c6277')

# %% [markdown]
# [к содержанию](#Содержание)

# %% [markdown]
# ## Задача 6
#
# Написать функцию `wc3(fname)`, которая принимает имя файла `fname` и возвращает словарь вида `{word: count}`, где `word` - слово из текстового файла в нижнем регистре, `count` - количество вхождений слова `word` в текст файла. Слова итогового словаря не должны содержать символы пунктуации (точки, запятые, и т.д.), а также сокращения `can't`, `ain't`, `'m`, `'ve`, `'ll`, `'d`, `'re`, `'ve`, `'s`, `n't`.
#
# Пример.
#
# Пусть файл `text.txt` содержит следующий текст:
#
# *Humpty Dumpty sat on a wall,
# Humpty Dumpty had a great fall.
# All the king's horses,
# And all the king's men,
# Couldn't put Humpty together again.*
#
# Тогда
# ```python
# >> wc3('text.txt')
# >> {'humpty': 3, 'dumpty': 2, 'sat': 1, 'on': 1, 'a': 2, 'wall': 1,
#     'had': 1, 'great': 1, 'fall': 1, 'all': 2, 'the': 2, 'king': 2,
#     'horses': 1, 'and': 1, 'men': 1, 'could': 1, 'put': 1,
#     'together': 1, 'again': 1}
# ```
#
# **(!)** При решении задачи размерами файла пренебречь.

# %%
# Решение
# def wc3(fname):
#     f = open(fname)
#     text = f.read()
#     f.close()
#     
#     text = ENTER YOUR CODE HERE
#     text = cleanup(text, ['can\'t','ain\'t','\'m','\'ve','\'ll','\'d','\'re','\'ve','\'s','n\'t'])
#     text = cleanup(text, '~`!@#$%^&*()[]{}_-+=;:\'"\\|,<.>/?')
#     
#     words = ENTER YOUR CODE HERE
#     
#     d = dict().fromkeys(words, 0)
#     for word in words:
#         ENTER YOUR CODE HERE
#     
#     return(d)

# %%
# Проверка

check_task(pack(wc3('text.txt')), 'abc70')
check_task(pack(wc3('text2.txt')), 'f6220')

# %% [markdown]
# [к содержанию](#Содержание)

# %% [markdown]
# ## Задача 7
#
# Написать функцию `wc4(fname)`, которая принимает имя файла `fname` и возвращает словарь вида `{word: count}`, где `word` - слово из текстового файла в нижнем регистре, `count` - количество вхождений слова `word` в текст файла. Слова итогового словаря не должны содержать символы пунктуации (точки, запятые, и т.д.), сокращения `can't`, `ain't`, `'m`, `'ve`, `'ll`, `'d`, `'re`, `'ve`, `'s`, `n't`, а также стоп-слова из файла `stopwords.txt`.
#
# Пример.
#
# Пусть файл `text.txt` содержит следующий текст:
#
# *Humpty Dumpty sat on a wall,
# Humpty Dumpty had a great fall.
# All the king's horses,
# And all the king's men,
# Couldn't put Humpty together again.*
#
# Тогда
# ```python
# >> wc4('text.txt')
# >> {'humpty': 3, 'dumpty': 2, 'sat': 1, 'wall': 1, 'had': 1,
#     'great': 1, 'fall': 1, 'king': 2, 'horses': 1, 'men': 1,
#     'could': 1, 'put': 1, 'together': 1, 'again': 1}
# ```
#
# **(!)** При решении задачи размерами файла пренебречь.

# %%
# def wc4(fname):
#     f = open(fname)
#     text = f.read()
#     f.close()
#     
#     f = open('stopwords.txt')
#     stopwords = ENTER YOUR CODE HERE
#     f.close()
#     
#     text = ENTER YOUR CODE HERE
#     text = cleanup(text, ['can\'t','ain\'t','\'m','\'ve','\'ll','\'d','\'re','\'ve','\'s','n\'t'])
#     text = cleanup(text, '~`!@#$%^&*()[]{}_-+=;:\'"\\|,<.>/?')
#     
#     words = ENTER YOUR CODE HERE
#     
#     d = dict().fromkeys(words, 0)
#     for word in words:
#         ENTER YOUR CODE HERE
#     
#     return(d)

# %%
# Проверка

check_task(pack(wc4('text.txt')), 'c5e4d')
check_task(pack(wc4('text2.txt')), '8df1d')

# %% [markdown]
# [к содержанию](#Содержание)

# %% [markdown]
# ## Задача 8
#
# Написать функцию `top_words1(fname, n)`, которая принимает имя файла `fname` и количество требуемых слов `n` и возвращает список из `n` наиболее часто встречающихся слов вида `(word, count)`, где `word` - слово из текстового файла, `count` - количество вхождений слова `word` в текст файла. Список должен быть упорядочен по убыванию значения `count`. Если `n` не указано, то список должен состоять из `5` слов.
# Слова итогового словаря не должны содержать символы пунктуации (точки, запятые, и т.д.), сокращения `can't`, `ain't`, `'m`, `'ve`, `'ll`, `'d`, `'re`, `'ve`, `'s`, `n't`, а также стоп-слова из файла `stopwords.txt`.
#
# Пример.
#
# Пусть файл `text.txt` содержит следующий текст:
#
# *Humpty Dumpty sat on a wall,
# Humpty Dumpty had a great fall.
# All the king's horses,
# And all the king's men,
# Couldn't put Humpty together again.*
#
# Тогда
# ```python
# >> top_words1('text.txt', 5)
# >> [('humpty', 3), ('dumpty', 2), ('king', 2), ('sat', 1), ('wall', 1)]
# ```
#
# **(!)** При решении задачи размерами файла пренебречь.

# %%
# Решение

# def top_words1(fname, n = 5):
#     d = wc4(fname)
#    
#     words = ENTER YOUR CODE HERE
#     words.sort(ENTER YOUR CODE HERE)
#     
#     return words[ENTER YOUR CODE HERE]

# %%
# Проверка

check_task(top_words1('text.txt', 5), '39ca3')
check_task(top_words1('text2.txt', 5), 'ff5f2')

# %% [markdown]
# [к содержанию](#Содержание)

# %% [markdown]
# ## Задача 9
#
# Требуется: написать функцию `top_words2(folder, n)`, которая принимает имя каталога `folder`, содержащего текстовые файлы, количество требуемых слов `n` и возвращает список из `n` наиболее часто встречающихся слов вида `(word, count)`,
# где `word` - слово, встречающееся в текстовых файлах, `count` - количество вхождений слова `word` в текстовые файлы. Список должен быть упорядочен по убыванию значения `count`. Если `n` не указано, то список должен состоять из 5 слов. Слова итогового словаря не должны содержать символы пунктуации (точки, запятые, и т.д.), сокращения `can't`, `ain't`, `'m`, `'ve`, `'ll`, `'d`, `'re`, `'ve`, `'s`, `n't`, а также стоп-слова из файла `stopwords.txt`.
#
# Пример.
#
# ```python
# >> top_words2('beatles')
# >> [('love', 391), ('know', 267), ('now', 198), ('yeah', 188), ('got', 173)]
# ```
#
# **(!)** При решении задачи размерами файла принебречь.

# %%
# Решение

# def top_words2(fname, n = 5):
#    
#     ENTER YOUR CODE HERE
#     
#     return words[ENTER YOUR CODE HERE]

# %%
# Проверка

check_task(top_words2('beatles', 5), 'c0545')
check_task(top_words2('beatles', 10), 'f1415')

# %% [markdown]
# [к содержанию](#Содержание)

# %% [markdown]
# ## Задача 10
#
# Дано: каталог `beatles` с файлами песен группы The Beatles и файл `beatles.txt` с описанием содержимого каталога.
# Каждая строка файла `beatles.txt`, кроме первой, которая является строкой заголовков, содержит поля:
# * `id` - идентификатор песни,
# * `Song` - название песни,
# * `Album` - название альбома,
# * `Year` - год выхода песни,
# * `File` - имя файла с текстом песни.
#
# Требуется: написать функцию `top_words3(fname, folder, n)`, которая принимает имя файла `fname` с описанием содержимого каталога, имя каталога `folder`, содержащего текстовые файлы, количество требуемых слов `n` и возвращает для каждого года с 1964 по 1970 включительно списки из `n` наиболее часто встречающихся слов вида `(word, count)`, где `word` - слово из текстовых файлов, `count` - количество вхождений слова `word` в текстовые файлы. Списки должны быть упорядочены по убыванию значения `count`. Если `n` не указано, то каждый список должен состоять из 5 слов. Слова итогового словаря не должны содержать символы пунктуации (точки, запятые, и т.д.), сокращения `can't`, `ain't`, `'m`, `'ve`, `'ll`, `'d`, `'re`, `'ve`, `'s`, `n't`, а также стоп-слова из файла `stopwords.txt`.
#
# Пример.
#
# ```python
# >> top_words3(folder = 'beatles', fname = 'beatles.txt', n = 3)
# >> {1964: [('love', 119), ('time', 37), ('baby', 37)],
#     1965: [('girl', 71), ('see', 49), ('love', 46)],
#     1966: [('day', 33), ('yellow', 27), ('submarine', 27)],
#     1967: [('love', 86), ('need', 59), ('say', 49)],
#     1968: [('know', 65), ('come', 56), ('number', 55)],
#     1969: [('love', 89), ('together', 63), ('now', 60)],
#     1970: [('yeah', 48), ('let', 44), ('back', 34)]}
# ```
#
# **(!)** При решении задачи размерами файла пренебречь.

# %%
# Решение

# def top_words3(folder, fname, n = 5):
#    
#     ENTER YOUR CODE HERE
#     
#     return ENTER YOUR CODE HERE

# %%
# Проверка

check_task(pack(top_words3(folder = 'beatles', fname = 'beatles.txt', n = 3)), '7cfdd')
check_task(pack(top_words3(folder = 'beatles', fname = 'beatles.txt', n = 5)), '268d1')

# %% [markdown]
# [к содержанию](#Содержание)
